# %% [markdown]
# <a href="https://colab.research.google.com/github/Sirfowahid/Transformers_Aspect_Based_Sentiment_Analysis/blob/main/Aspect_Based_Contextual_Analysis_Using_BERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Making The Dataset Ready

# %% [markdown]
# # New Section

# %%
# !pip install -q transformers datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 25.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.1/519.1 kB 27.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 19.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 43.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.5 MB/s eta 0:00:00

# %%
# !pip install -q transformers[torch]
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 5.3 MB/s eta 0:00:00

# %%
# !pip install -q accelerate -U

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import transformers
import datasets
import torch

from sklearn.metrics import f1_score,accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
df = pd.read_excel('/content/drive/MyDrive/BERT/Copy of Book Review Aspect final.xlsx')
df.head()
# Out:
#     id                                               Name  \
# 0   89                           নামাজ আদায়ের সঠিক পদ্ধতি
# 1    1  ছহীহ নূরানী বাংলা উচ্চারণ সহজ সরল বঙ্গানুবাদ ও...
# 2  195  ইসলামের দৃষ্টিতে পর্দার হুকুম ও নারীর মর্যাদা ...
# 3  343           আশরাফ আলি থানভির প্রিয়গল্প-২ (হার্ডকভার)
# 4  465  ছড়ায় ছন্দে চিড়িয়াখানা (প্রাণী) (হার্ডকভার)  ছো...
#
#                                          Writer_Name                 Category  \
# 0  حكيم الامت مولانا اشرف علي تهانوي رح ( হাকীমুল...              সালাত/নামায
# 1              মাওলানা ফরিদ উদ্দিন আহাম্মদ (অনুবাদক)             নূরানী কুরআন
# 2  حكيم الامت مولانا اشرف علي تهانوي رح ( হাকীমুল...              পর্দা বিধান
# 3  حكيم الامت مولانا اشرف علي تهانوي رح ( হাকীমুল...              ইসলামি গল্প
# 4                                      ইয়াছিন আরাফাত  বয়স যখন ৪-৮: বাংলা ছড়া
#
#    Rating                                             Review      Site  \
# 0       2                                  কিছু পৃষ্ঠা ফাঁকা  Rokomari
# 1       1                      প্রত্যাশার নীচে কাগজের গুণমান  Rokomari
# 2       1  সোলেমানীয়া বুক হাউস প্রকাশনীর সব বই গুলিতে প্র...  Rokomari
# 3       1  বইয়ের কাভার আর সূচিপত্র প্রিয়গল্প-২, ভিতরে প্র...  Rokomari
# 4       2  কালার , পেজ, লেখার কুয়ালিটি খুবই নিম্ন মানের ,...  Rokomari
#
#   sentiment label Comment About  Unnamed: 10
# 0  negative     0           NaN            0
# 1  negative     0           NaN            0
# 2  negative     0           NaN            0
# 3  negative     0           NaN            0
# 4  negative     0           NaN            0

# %%
df.columns
# Out:
# Index(['id', 'Name', 'Writer_Name', 'Category', 'Rating', 'Review', 'Site',
#        'sentiment', 'label', 'Comment About', 'Unnamed: 10'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   id       Rating  Unnamed: 10
# count    2054.000000  2054.000000  2054.000000
# mean    19299.654333     2.028724     0.847614
# std     14563.784168     0.980895     0.359482
# min         1.000000     1.000000     0.000000
# 25%      7867.000000     1.000000     1.000000
# 50%     17228.500000     2.000000     1.000000
# 75%     30823.250000     3.000000     1.000000
# max    157994.000000     5.000000     1.000000

# %%
df.tail(10)
# Out:
#          id                                               Name  \
# 2044  38668   সোফির জগৎ (হার্ডকভার)  আন্তর্জাতিক পুরস্কার প...
# 2045  38686  সোফির জগৎ (হার্ডকভার)  পাশ্চাত্য দর্শনের সংক্ষ...
# 2046  38760                          আরজ আলীর রম্য (হার্ডকভার)
# 2047  38806                        জেমস বন্ড সমগ্র (হার্ডকভার)
# 2048  38887        পাইথন প্রোগ্রামিং ল্যাংগুয়েজ ৩ (হার্ডকভার)
# 2049  38891        পাইথন প্রোগ্রামিং ল্যাংগুয়েজ ৩ (হার্ডকভার)
# 2050  38892        পাইথন প্রোগ্রামিং ল্যাংগুয়েজ ৩ (হার্ডকভার)
# 2051  38906                                 নিলামে পাঁচটি শব্দ
# 2052  38979                        Dipu Number Two (Hardcover)
# 2053  38988   মাইন্ড ওয়ারস (পেপারব্যাক)  সরকার, মিডিয়া ও গো...
#
#                Writer_Name                                           Category  \
# 2044      ইয়স্তেন গার্ডার                                    পাশ্চাত্য দর্শন
# 2045      ইয়স্তেন গার্ডার                                     অনুবাদ উপন্যাস
# 2046          ইয়াছির মিশুক                                  ব্যঙ্গ ও রম্যরচনা
# 2047          ইয়ান ফ্লেমিং   রহস্য, গোয়েন্দা, ভৌতিক, মিথ, থ্রিলার, ও অ্যাড...
# 2048   ইয়াসির আরাফাত রাতুল                                  পাইথন প্রোগ্রামিং
# 2049   ইয়াসির আরাফাত রাতুল                                  পাইথন প্রোগ্রামিং
# 2050   ইয়াসির আরাফাত রাতুল                                  পাইথন প্রোগ্রামিং
# 2051            ইয়াসির মনন                                       সমকালীন গল্প
# 2052  Muhammod Zafar Iqbal                          Novel: Children and Teens
# 2053        ম্যারি ডি. জনস          ডিটেকটিভ, ইন্টেলিজেন্স ও সিক্রেট এজেন্সি
#
#       Rating                                             Review      Site  \
# 2044       3                                               ভালো  Rokomari
# 2045       3                                              ভালো  Rokomari
# 2046       3  আমি বইটা কিনার সময় প্রথমে ভেবেছিলাম এটা প্যারা...  Rokomari
# 2047       3                                          সুন্দর বই  Rokomari
# 2048       3  যতটা আশা নিয়ে বইটি কিনেছিলাম আসলেই সেটা সে রকম...  Rokomari
# 2049       3                                     এই বইগুলি ভাল।  Rokomari
# 2050       3                                                ভাল  Rokomari
# 2051       3  ছোটগল্প! আকারে ছোট। গল্প বিস্তার কম...কথা সহজ ...  Rokomari
# 2052       3  বইটির প্রধান চরিত্র দিপু। সবাই তাকে চেনে দিপু ...  Rokomari
# 2053       3                              অনুবাদ যথেষ্ট ভাল না।  Rokomari
#
#      sentiment label Comment About  Unnamed: 10
# 2044   neutral     1           NaN            1
# 2045   neutral     1           NaN            1
# 2046   neutral     1           NaN            1
# 2047   neutral     1           NaN            1
# 2048   neutral     1           NaN            1
# 2049   neutral     1           NaN            1
# 2050   neutral     1           NaN            1
# 2051   neutral     1           NaN            1
# 2052   neutral     1           NaN            1
# 2053   neutral     1           NaN            1

# %%
df_mod = df[['Review','label']].dropna()

# %%
df_mod.describe()
# Out:
#        Review  label
# count    2054   2054
# unique   1604      4
# top       ভাল      0
# freq       87   1123

# %%
df_mod.label.unique()
# Out:
# array([0, 2, 1, '  '], dtype=object)

# %%
df_mod[df['label']=='  ']
# Out:
#       Review label
# 634  ঠিক আছে

# %%
df_mod.drop(index=634,inplace=True)

# %%
df_mod.label.unique()
# Out:
# array([0, 2, 1], dtype=object)

# %%
df_mod.label.hist()
# Out:
# <Axes: >

# %%
df_mod.head()
# Out:
#                                               Review label
# 0                                  কিছু পৃষ্ঠা ফাঁকা     0
# 1                      প্রত্যাশার নীচে কাগজের গুণমান     0
# 2  সোলেমানীয়া বুক হাউস প্রকাশনীর সব বই গুলিতে প্র...     0
# 3  বইয়ের কাভার আর সূচিপত্র প্রিয়গল্প-২, ভিতরে প্র...     0
# 4  কালার , পেজ, লেখার কুয়ালিটি খুবই নিম্ন মানের ,...     0

# %%
df_mod.columns = ['sentence','label']
df_mod.to_csv('data.csv',index=None)

# %% [markdown]
# # Training BERT

# %%
from datasets import load_dataset
raw_dataset = load_dataset('csv',data_files='data.csv')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 2053
#     })
# })

# %%
split = raw_dataset['train'].train_test_split(test_size=0.2,seed=42)

# %%
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 1642
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 411
#     })
# })

# %%
checkpoint = 'bert-base-multilingual-cased'

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]

# %%
def tokenizer_fn(batch):
  return tokenizer(batch['sentence'],truncation=True)

# %%
tokenized_dataset = split.map(tokenizer_fn,batched=True)
# Out:
# Map:   0%|          | 0/1642 [00:00<?, ? examples/s]
# Map:   0%|          | 0/411 [00:00<?, ? examples/s]

# %%
from transformers import AutoModelForSequenceClassification

# %%
model = AutoModelForSequenceClassification.from_pretrained(checkpoint,num_labels=3)
# Out:
# Downloading model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(119547, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
# !pip install -q torchinfo

# %%
import accelerate

# %%
accelerate.__version__
# Out:
# '0.21.0'

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# BertForSequenceClassification                           --
# ├─BertModel: 1-1                                        --
# │    └─BertEmbeddings: 2-1                              --
# │    │    └─Embedding: 3-1                              91,812,096
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─Embedding: 3-3                              1,536
# │    │    └─LayerNorm: 3-4                              1,536
# │    │    └─Dropout: 3-5                                --
# │    └─BertEncoder: 2-2                                 --
# │    │    └─ModuleList: 3-6                             85,054,464
# │    └─BertPooler: 2-3                                  --
# │    │    └─Linear: 3-7                                 590,592
# │    │    └─Tanh: 3-8                                   --
# ├─Dropout: 1-2                                          --
# ├─Linear: 1-3                                           2,307
# ================================================================================
# Total params: 177,855,747
# Trainable params: 177,855,747
# Non-trainable params: 0
# ================================================================================

# %%
from transformers import Trainer,TrainingArguments

# %%
training_args = TrainingArguments(
    output_dir = 'training_dir',
    evaluation_strategy = 'epoch',
    save_strategy='epoch',
    num_train_epochs = 10,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=64
)

# %%
def compute_metrics(logits_and_labels):
  logits,labels = logits_and_labels
  predictions = np.argmax(logits,axis=-1)
  acc = np.mean(predictions == labels)
  f1 = f1_score(labels,predictions,average='macro')
  return {'accuracy':acc,'f1':f1}

# %%
trainer = Trainer(
    model,
    training_args,
    train_dataset=tokenized_dataset['train'],
    eval_dataset=tokenized_dataset['test'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='1030' max='1030' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1030/1030 09:26, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.830643</td>
#       <td>0.535280</td>
#       <td>0.348992</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.749078</td>
#       <td>0.659367</td>
#       <td>0.428100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>0.715148</td>
#       <td>0.712895</td>
#       <td>0.483263</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>0.762706</td>
#       <td>0.669100</td>
#       <td>0.456105</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.723600</td>
#       <td>0.683183</td>
#       <td>0.737226</td>
#       <td>0.498790</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.723600</td>
#       <td>0.785797</td>
#       <td>0.727494</td>
#       <td>0.597064</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.723600</td>
#       <td>0.901157</td>
#       <td>0.756691</td>
#       <td>0.634767</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.723600</td>
#       <td>0.845936</td>
#       <td>0.708029</td>
#       <td>0.613216</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.723600</td>
#       <td>0.918802</td>
#       <td>0.712895</td>
#       <td>0.624178</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.349100</td>
#       <td>0.974500</td>
#       <td>0.732360</td>
#       <td>0.651845</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1030, training_loss=0.527901040234612, metrics={'train_runtime': 570.1082, 'train_samples_per_second': 28.802, 'train_steps_per_second': 1.807, 'total_flos': 1040434732213128.0, 'train_loss': 0.527901040234612, 'epoch': 10.0})

# %%
# !ls training_dir
# Out:
# checkpoint-103	 checkpoint-309  checkpoint-618  checkpoint-927
# checkpoint-1030  checkpoint-412  checkpoint-721  runs
# checkpoint-206	 checkpoint-515  checkpoint-824

# %% [markdown]
# # Saving The Model Pipeline

# %%
from transformers import pipeline

# %%
savedmodel = pipeline('text-classification',
                      model='training_dir/checkpoint-618',
                      device=0)

# %%
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 411
# })

# %%
test_pred = savedmodel(split['test']['sentence'])

# %%
test_pred
# Out:
# [{'label': 'LABEL_0', 'score': 0.945760190486908},
#  {'label': 'LABEL_0', 'score': 0.7947132587432861},
#  {'label': 'LABEL_0', 'score': 0.9582508206367493},
#  {'label': 'LABEL_1', 'score': 0.917050838470459},
#  {'label': 'LABEL_0', 'score': 0.9567599296569824},
#  {'label': 'LABEL_1', 'score': 0.8851845264434814},
#  {'label': 'LABEL_0', 'score': 0.9585467576980591},
#  {'label': 'LABEL_0', 'score': 0.9485486149787903},
#  {'label': 'LABEL_1', 'score': 0.9551902413368225},
#  {'label': 'LABEL_0', 'score': 0.7947132587432861},
#  {'label': 'LABEL_0', 'score': 0.9311031103134155},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.9347336292266846},
#  {'label': 'LABEL_0', 'score': 0.8702580332756042},
#  {'label': 'LABEL_0', 'score': 0.9561173319816589},
#  {'label': 'LABEL_0', 'score': 0.8928767442703247},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9607122540473938},
#  {'label': 'LABEL_0', 'score': 0.8158867359161377},
#  {'label': 'LABEL_1', 'score': 0.9405287504196167},
#  {'label': 'LABEL_0', 'score': 0.9562191963195801},
#  {'label': 'LABEL_0', 'score': 0.959218442440033},
#  {'label': 'LABEL_1', 'score': 0.9328145384788513},
#  {'label': 'LABEL_1', 'score': 0.7180502414703369},
#  {'label': 'LABEL_0', 'score': 0.8795968890190125},
#  {'label': 'LABEL_1', 'score': 0.8993228077888489},
#  {'label': 'LABEL_0', 'score': 0.9477373361587524},
#  {'label': 'LABEL_0', 'score': 0.954755425453186},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9573597311973572},
#  {'label': 'LABEL_0', 'score': 0.961300253868103},
#  {'label': 'LABEL_0', 'score': 0.9488290548324585},
#  {'label': 'LABEL_1', 'score': 0.9369895458221436},
#  {'label': 'LABEL_1', 'score': 0.612762451171875},
#  {'label': 'LABEL_1', 'score': 0.9348948001861572},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9575283527374268},
#  {'label': 'LABEL_1', 'score': 0.9303948283195496},
#  {'label': 'LABEL_1', 'score': 0.9252452850341797},
#  {'label': 'LABEL_0', 'score': 0.957760751247406},
#  {'label': 'LABEL_0', 'score': 0.7893823981285095},
#  {'label': 'LABEL_0', 'score': 0.9693098664283752},
#  {'label': 'LABEL_2', 'score': 0.5638532042503357},
#  {'label': 'LABEL_0', 'score': 0.9556378126144409},
#  {'label': 'LABEL_1', 'score': 0.9436333775520325},
#  {'label': 'LABEL_0', 'score': 0.905903160572052},
#  {'label': 'LABEL_1', 'score': 0.9162130951881409},
#  {'label': 'LABEL_0', 'score': 0.7106427550315857},
#  {'label': 'LABEL_0', 'score': 0.7150664329528809},
#  {'label': 'LABEL_2', 'score': 0.5603160858154297},
#  {'label': 'LABEL_0', 'score': 0.9459671974182129},
#  {'label': 'LABEL_0', 'score': 0.9501011967658997},
#  {'label': 'LABEL_0', 'score': 0.959955096244812},
#  {'label': 'LABEL_1', 'score': 0.7218949794769287},
#  {'label': 'LABEL_0', 'score': 0.9199126362800598},
#  {'label': 'LABEL_0', 'score': 0.955049455165863},
#  {'label': 'LABEL_0', 'score': 0.907232940196991},
#  {'label': 'LABEL_0', 'score': 0.9508401155471802},
#  {'label': 'LABEL_0', 'score': 0.9467935562133789},
#  {'label': 'LABEL_1', 'score': 0.9112237095832825},
#  {'label': 'LABEL_0', 'score': 0.9587252140045166},
#  {'label': 'LABEL_0', 'score': 0.8991947174072266},
#  {'label': 'LABEL_1', 'score': 0.5977620482444763},
#  {'label': 'LABEL_0', 'score': 0.921889066696167},
#  {'label': 'LABEL_0', 'score': 0.9606459140777588},
#  {'label': 'LABEL_0', 'score': 0.74361652135849},
#  {'label': 'LABEL_0', 'score': 0.9525676369667053},
#  {'label': 'LABEL_0', 'score': 0.9571973085403442},
#  {'label': 'LABEL_0', 'score': 0.9525769352912903},
#  {'label': 'LABEL_1', 'score': 0.9411516785621643},
#  {'label': 'LABEL_1', 'score': 0.6874625086784363},
#  {'label': 'LABEL_0', 'score': 0.9399775862693787},
#  {'label': 'LABEL_0', 'score': 0.9591479301452637},
#  {'label': 'LABEL_1', 'score': 0.6350429058074951},
#  {'label': 'LABEL_0', 'score': 0.9570916891098022},
#  {'label': 'LABEL_0', 'score': 0.5519843101501465},
#  {'label': 'LABEL_0', 'score': 0.8894952535629272},
#  {'label': 'LABEL_1', 'score': 0.9020676612854004},
#  {'label': 'LABEL_0', 'score': 0.9592968821525574},
#  {'label': 'LABEL_1', 'score': 0.7218949794769287},
#  {'label': 'LABEL_0', 'score': 0.8597502112388611},
#  {'label': 'LABEL_1', 'score': 0.9630638957023621},
#  {'label': 'LABEL_0', 'score': 0.7705202698707581},
#  {'label': 'LABEL_0', 'score': 0.9607122540473938},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.5573204755783081},
#  {'label': 'LABEL_1', 'score': 0.6350429058074951},
#  {'label': 'LABEL_0', 'score': 0.9533666968345642},
#  {'label': 'LABEL_0', 'score': 0.9605975151062012},
#  {'label': 'LABEL_1', 'score': 0.9480673670768738},
#  {'label': 'LABEL_0', 'score': 0.955669105052948},
#  {'label': 'LABEL_1', 'score': 0.9460210800170898},
#  {'label': 'LABEL_1', 'score': 0.9282892346382141},
#  {'label': 'LABEL_1', 'score': 0.9290006160736084},
#  {'label': 'LABEL_0', 'score': 0.955000102519989},
#  {'label': 'LABEL_0', 'score': 0.938626229763031},
#  {'label': 'LABEL_1', 'score': 0.9120267629623413},
#  {'label': 'LABEL_1', 'score': 0.5080739259719849},
#  {'label': 'LABEL_1', 'score': 0.8841754198074341},
#  {'label': 'LABEL_1', 'score': 0.9628189206123352},
#  {'label': 'LABEL_0', 'score': 0.8265287280082703},
#  {'label': 'LABEL_0', 'score': 0.9081709384918213},
#  {'label': 'LABEL_1', 'score': 0.9136236310005188},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9597352147102356},
#  {'label': 'LABEL_0', 'score': 0.9558395147323608},
#  {'label': 'LABEL_1', 'score': 0.9010941386222839},
#  {'label': 'LABEL_1', 'score': 0.9137941002845764},
#  {'label': 'LABEL_0', 'score': 0.9567945003509521},
#  {'label': 'LABEL_1', 'score': 0.9315202236175537},
#  {'label': 'LABEL_0', 'score': 0.9595231413841248},
#  {'label': 'LABEL_0', 'score': 0.9576196074485779},
#  {'label': 'LABEL_0', 'score': 0.9559709429740906},
#  {'label': 'LABEL_1', 'score': 0.9281023740768433},
#  {'label': 'LABEL_1', 'score': 0.9488573670387268},
#  {'label': 'LABEL_1', 'score': 0.9667186141014099},
#  {'label': 'LABEL_1', 'score': 0.9130883812904358},
#  {'label': 'LABEL_0', 'score': 0.9288347959518433},
#  {'label': 'LABEL_0', 'score': 0.9371909499168396},
#  {'label': 'LABEL_0', 'score': 0.9480199813842773},
#  {'label': 'LABEL_2', 'score': 0.5638532042503357},
#  {'label': 'LABEL_1', 'score': 0.7180502414703369},
#  {'label': 'LABEL_0', 'score': 0.9531696438789368},
#  {'label': 'LABEL_1', 'score': 0.8005448579788208},
#  {'label': 'LABEL_0', 'score': 0.6793633699417114},
#  {'label': 'LABEL_1', 'score': 0.9203790426254272},
#  {'label': 'LABEL_0', 'score': 0.9528161883354187},
#  {'label': 'LABEL_0', 'score': 0.8597502112388611},
#  {'label': 'LABEL_0', 'score': 0.9533205628395081},
#  {'label': 'LABEL_0', 'score': 0.9570558667182922},
#  {'label': 'LABEL_0', 'score': 0.8916247487068176},
#  {'label': 'LABEL_2', 'score': 0.5608869791030884},
#  {'label': 'LABEL_1', 'score': 0.9165371656417847},
#  {'label': 'LABEL_0', 'score': 0.9690332412719727},
#  {'label': 'LABEL_0', 'score': 0.9330703020095825},
#  {'label': 'LABEL_1', 'score': 0.8395345211029053},
#  {'label': 'LABEL_0', 'score': 0.930900514125824},
#  {'label': 'LABEL_0', 'score': 0.9528709650039673},
#  {'label': 'LABEL_1', 'score': 0.7686401605606079},
#  {'label': 'LABEL_0', 'score': 0.9399775862693787},
#  {'label': 'LABEL_0', 'score': 0.9535850882530212},
#  {'label': 'LABEL_0', 'score': 0.9547529220581055},
#  {'label': 'LABEL_1', 'score': 0.9436333775520325},
#  {'label': 'LABEL_1', 'score': 0.898226261138916},
#  {'label': 'LABEL_1', 'score': 0.9514782428741455},
#  {'label': 'LABEL_1', 'score': 0.9045843482017517},
#  {'label': 'LABEL_0', 'score': 0.955493152141571},
#  {'label': 'LABEL_0', 'score': 0.6091922521591187},
#  {'label': 'LABEL_1', 'score': 0.9382032752037048},
#  {'label': 'LABEL_0', 'score': 0.9562714099884033},
#  {'label': 'LABEL_1', 'score': 0.8092602491378784},
#  {'label': 'LABEL_0', 'score': 0.962805986404419},
#  {'label': 'LABEL_0', 'score': 0.9412903189659119},
#  {'label': 'LABEL_0', 'score': 0.6825001239776611},
#  {'label': 'LABEL_2', 'score': 0.5638532042503357},
#  {'label': 'LABEL_0', 'score': 0.9564001560211182},
#  {'label': 'LABEL_0', 'score': 0.9575096368789673},
#  {'label': 'LABEL_0', 'score': 0.8278815746307373},
#  {'label': 'LABEL_1', 'score': 0.773690402507782},
#  {'label': 'LABEL_0', 'score': 0.9526517987251282},
#  {'label': 'LABEL_0', 'score': 0.9456446766853333},
#  {'label': 'LABEL_0', 'score': 0.9571976065635681},
#  {'label': 'LABEL_0', 'score': 0.9401920437812805},
#  {'label': 'LABEL_0', 'score': 0.9596101641654968},
#  {'label': 'LABEL_0', 'score': 0.9528766870498657},
#  {'label': 'LABEL_1', 'score': 0.7616671323776245},
#  {'label': 'LABEL_0', 'score': 0.9426138401031494},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.957686185836792},
#  {'label': 'LABEL_1', 'score': 0.6774633526802063},
#  {'label': 'LABEL_1', 'score': 0.9259299039840698},
#  {'label': 'LABEL_0', 'score': 0.9526945352554321},
#  {'label': 'LABEL_1', 'score': 0.8036878108978271},
#  {'label': 'LABEL_0', 'score': 0.9563081860542297},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.8550039529800415},
#  {'label': 'LABEL_0', 'score': 0.947541356086731},
#  {'label': 'LABEL_0', 'score': 0.9583142995834351},
#  {'label': 'LABEL_0', 'score': 0.950015127658844},
#  {'label': 'LABEL_0', 'score': 0.9568723440170288},
#  {'label': 'LABEL_0', 'score': 0.9591322541236877},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.9585899114608765},
#  {'label': 'LABEL_1', 'score': 0.6350429058074951},
#  {'label': 'LABEL_1', 'score': 0.9010941386222839},
#  {'label': 'LABEL_0', 'score': 0.9328303933143616},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9456634521484375},
#  {'label': 'LABEL_1', 'score': 0.9470039010047913},
#  {'label': 'LABEL_0', 'score': 0.9476976990699768},
#  {'label': 'LABEL_0', 'score': 0.9272780418395996},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9605975151062012},
#  {'label': 'LABEL_0', 'score': 0.9559709429740906},
#  {'label': 'LABEL_0', 'score': 0.9438515305519104},
#  {'label': 'LABEL_1', 'score': 0.9528565406799316},
#  {'label': 'LABEL_0', 'score': 0.9550965428352356},
#  {'label': 'LABEL_1', 'score': 0.5927459597587585},
#  {'label': 'LABEL_0', 'score': 0.9486337304115295},
#  {'label': 'LABEL_1', 'score': 0.7745160460472107},
#  {'label': 'LABEL_1', 'score': 0.6590596437454224},
#  {'label': 'LABEL_0', 'score': 0.9559709429740906},
#  {'label': 'LABEL_0', 'score': 0.9518761038780212},
#  {'label': 'LABEL_0', 'score': 0.9507705569267273},
#  {'label': 'LABEL_0', 'score': 0.9479674100875854},
#  {'label': 'LABEL_1', 'score': 0.8756744265556335},
#  {'label': 'LABEL_0', 'score': 0.9561654925346375},
#  {'label': 'LABEL_0', 'score': 0.9412903189659119},
#  {'label': 'LABEL_2', 'score': 0.5638532042503357},
#  {'label': 'LABEL_1', 'score': 0.9581994414329529},
#  {'label': 'LABEL_1', 'score': 0.7745160460472107},
#  {'label': 'LABEL_1', 'score': 0.9607614278793335},
#  {'label': 'LABEL_0', 'score': 0.9391725063323975},
#  {'label': 'LABEL_1', 'score': 0.8460814952850342},
#  {'label': 'LABEL_1', 'score': 0.622359037399292},
#  {'label': 'LABEL_0', 'score': 0.9550638198852539},
#  {'label': 'LABEL_0', 'score': 0.9581203460693359},
#  {'label': 'LABEL_0', 'score': 0.9570353031158447},
#  {'label': 'LABEL_1', 'score': 0.867592453956604},
#  {'label': 'LABEL_0', 'score': 0.8597502112388611},
#  {'label': 'LABEL_1', 'score': 0.8581224679946899},
#  {'label': 'LABEL_0', 'score': 0.8538842797279358},
#  {'label': 'LABEL_0', 'score': 0.9052137732505798},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.959955096244812},
#  {'label': 'LABEL_1', 'score': 0.6675949096679688},
#  {'label': 'LABEL_1', 'score': 0.9133690595626831},
#  {'label': 'LABEL_1', 'score': 0.8647322654724121},
#  {'label': 'LABEL_0', 'score': 0.9584372639656067},
#  {'label': 'LABEL_0', 'score': 0.9574234485626221},
#  {'label': 'LABEL_0', 'score': 0.9282800555229187},
#  {'label': 'LABEL_0', 'score': 0.9575302004814148},
#  {'label': 'LABEL_1', 'score': 0.9416720867156982},
#  {'label': 'LABEL_0', 'score': 0.9566876888275146},
#  {'label': 'LABEL_1', 'score': 0.9010941386222839},
#  {'label': 'LABEL_1', 'score': 0.9601235389709473},
#  {'label': 'LABEL_1', 'score': 0.8544746041297913},
#  {'label': 'LABEL_0', 'score': 0.7616628408432007},
#  {'label': 'LABEL_1', 'score': 0.9498149752616882},
#  {'label': 'LABEL_0', 'score': 0.9376348257064819},
#  {'label': 'LABEL_1', 'score': 0.9157325029373169},
#  {'label': 'LABEL_0', 'score': 0.9560152292251587},
#  {'label': 'LABEL_0', 'score': 0.9577898383140564},
#  {'label': 'LABEL_1', 'score': 0.5340393781661987},
#  {'label': 'LABEL_1', 'score': 0.8908095359802246},
#  {'label': 'LABEL_0', 'score': 0.6992595791816711},
#  {'label': 'LABEL_1', 'score': 0.9580866098403931},
#  {'label': 'LABEL_0', 'score': 0.9556390047073364},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.7790014147758484},
#  {'label': 'LABEL_0', 'score': 0.9239092469215393},
#  {'label': 'LABEL_1', 'score': 0.8974027633666992},
#  {'label': 'LABEL_0', 'score': 0.9690332412719727},
#  {'label': 'LABEL_1', 'score': 0.9394205212593079},
#  {'label': 'LABEL_0', 'score': 0.9563214778900146},
#  {'label': 'LABEL_1', 'score': 0.9220643043518066},
#  {'label': 'LABEL_1', 'score': 0.7599985599517822},
#  {'label': 'LABEL_1', 'score': 0.8881664872169495},
#  {'label': 'LABEL_0', 'score': 0.9483030438423157},
#  {'label': 'LABEL_1', 'score': 0.9390978217124939},
#  {'label': 'LABEL_1', 'score': 0.6871389746665955},
#  {'label': 'LABEL_0', 'score': 0.953070878982544},
#  {'label': 'LABEL_0', 'score': 0.9239092469215393},
#  {'label': 'LABEL_0', 'score': 0.6752086877822876},
#  {'label': 'LABEL_1', 'score': 0.7180502414703369},
#  {'label': 'LABEL_1', 'score': 0.9117907285690308},
#  {'label': 'LABEL_0', 'score': 0.9536519050598145},
#  {'label': 'LABEL_1', 'score': 0.9052209258079529},
#  {'label': 'LABEL_0', 'score': 0.9568629860877991},
#  {'label': 'LABEL_1', 'score': 0.8771699666976929},
#  {'label': 'LABEL_1', 'score': 0.9547775983810425},
#  {'label': 'LABEL_0', 'score': 0.9479199647903442},
#  {'label': 'LABEL_0', 'score': 0.9473761916160583},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.958731472492218},
#  {'label': 'LABEL_1', 'score': 0.7180502414703369},
#  {'label': 'LABEL_1', 'score': 0.9436333775520325},
#  {'label': 'LABEL_1', 'score': 0.9157325029373169},
#  {'label': 'LABEL_0', 'score': 0.7211185097694397},
#  {'label': 'LABEL_0', 'score': 0.7186148166656494},
#  {'label': 'LABEL_0', 'score': 0.9555380344390869},
#  {'label': 'LABEL_1', 'score': 0.9601235389709473},
#  {'label': 'LABEL_1', 'score': 0.9209458231925964},
#  {'label': 'LABEL_0', 'score': 0.9345205426216125},
#  {'label': 'LABEL_1', 'score': 0.9594190120697021},
#  {'label': 'LABEL_1', 'score': 0.8134162425994873},
#  {'label': 'LABEL_0', 'score': 0.9478316903114319},
#  {'label': 'LABEL_0', 'score': 0.9584554433822632},
#  {'label': 'LABEL_1', 'score': 0.9517895579338074},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.9588449001312256},
#  {'label': 'LABEL_0', 'score': 0.9595719575881958},
#  {'label': 'LABEL_1', 'score': 0.9147310853004456},
#  {'label': 'LABEL_1', 'score': 0.6666944026947021},
#  {'label': 'LABEL_0', 'score': 0.9608507752418518},
#  {'label': 'LABEL_0', 'score': 0.9054617881774902},
#  {'label': 'LABEL_0', 'score': 0.9470357894897461},
#  {'label': 'LABEL_0', 'score': 0.9543659090995789},
#  {'label': 'LABEL_0', 'score': 0.9615313410758972},
#  {'label': 'LABEL_0', 'score': 0.9287936687469482},
#  {'label': 'LABEL_1', 'score': 0.9532071352005005},
#  {'label': 'LABEL_0', 'score': 0.9586459994316101},
#  {'label': 'LABEL_1', 'score': 0.758329451084137},
#  {'label': 'LABEL_1', 'score': 0.9290006160736084},
#  {'label': 'LABEL_0', 'score': 0.9552193284034729},
#  {'label': 'LABEL_0', 'score': 0.9356306195259094},
#  {'label': 'LABEL_0', 'score': 0.957952082157135},
#  {'label': 'LABEL_1', 'score': 0.8864079117774963},
#  {'label': 'LABEL_0', 'score': 0.8291064500808716},
#  {'label': 'LABEL_0', 'score': 0.9440677165985107},
#  {'label': 'LABEL_0', 'score': 0.8836899399757385},
#  {'label': 'LABEL_0', 'score': 0.9559066891670227},
#  {'label': 'LABEL_1', 'score': 0.8818116188049316},
#  {'label': 'LABEL_1', 'score': 0.9330441355705261},
#  {'label': 'LABEL_0', 'score': 0.9540326595306396},
#  {'label': 'LABEL_1', 'score': 0.5310049653053284},
#  {'label': 'LABEL_1', 'score': 0.9495335817337036},
#  {'label': 'LABEL_1', 'score': 0.9520150423049927},
#  {'label': 'LABEL_0', 'score': 0.959955096244812},
#  {'label': 'LABEL_0', 'score': 0.9559614658355713},
#  {'label': 'LABEL_1', 'score': 0.9303457736968994},
#  {'label': 'LABEL_1', 'score': 0.9135950803756714},
#  {'label': 'LABEL_1', 'score': 0.6569483876228333},
#  {'label': 'LABEL_0', 'score': 0.5492740869522095},
#  {'label': 'LABEL_1', 'score': 0.9614403247833252},
#  {'label': 'LABEL_0', 'score': 0.9527312517166138},
#  {'label': 'LABEL_0', 'score': 0.9548121094703674},
#  {'label': 'LABEL_0', 'score': 0.930740237236023},
#  {'label': 'LABEL_2', 'score': 0.4937778413295746},
#  {'label': 'LABEL_1', 'score': 0.7630438208580017},
#  {'label': 'LABEL_0', 'score': 0.9601346254348755},
#  {'label': 'LABEL_0', 'score': 0.6793633699417114},
#  {'label': 'LABEL_1', 'score': 0.9303313493728638},
#  {'label': 'LABEL_0', 'score': 0.9584931135177612},
#  {'label': 'LABEL_0', 'score': 0.9592966437339783},
#  {'label': 'LABEL_0', 'score': 0.9589748978614807},
#  {'label': 'LABEL_0', 'score': 0.9569374918937683},
#  {'label': 'LABEL_0', 'score': 0.9588444828987122},
#  {'label': 'LABEL_0', 'score': 0.958794355392456},
#  {'label': 'LABEL_1', 'score': 0.9658476710319519},
#  {'label': 'LABEL_1', 'score': 0.9559043049812317},
#  {'label': 'LABEL_0', 'score': 0.9520741105079651},
#  {'label': 'LABEL_0', 'score': 0.9561905264854431},
#  {'label': 'LABEL_1', 'score': 0.6050687432289124},
#  {'label': 'LABEL_1', 'score': 0.883082389831543},
#  {'label': 'LABEL_0', 'score': 0.9474644660949707},
#  {'label': 'LABEL_0', 'score': 0.9601441025733948},
#  {'label': 'LABEL_1', 'score': 0.9010941386222839},
#  {'label': 'LABEL_0', 'score': 0.9571444392204285},
#  {'label': 'LABEL_1', 'score': 0.95047926902771},
#  {'label': 'LABEL_0', 'score': 0.9611348509788513},
#  {'label': 'LABEL_0', 'score': 0.9430155754089355},
#  {'label': 'LABEL_0', 'score': 0.9598022103309631},
#  {'label': 'LABEL_1', 'score': 0.6350429058074951},
#  {'label': 'LABEL_1', 'score': 0.9282892346382141},
#  {'label': 'LABEL_0', 'score': 0.9593176245689392},
#  {'label': 'LABEL_1', 'score': 0.9130883812904358},
#  {'label': 'LABEL_1', 'score': 0.9133895635604858},
#  {'label': 'LABEL_0', 'score': 0.9605851769447327},
#  {'label': 'LABEL_0', 'score': 0.9592713117599487},
#  {'label': 'LABEL_1', 'score': 0.9601235389709473},
#  {'label': 'LABEL_0', 'score': 0.9555380344390869},
#  {'label': 'LABEL_0', 'score': 0.858385443687439},
#  {'label': 'LABEL_0', 'score': 0.9504413604736328},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.8523526787757874},
#  {'label': 'LABEL_1', 'score': 0.8924439549446106},
#  {'label': 'LABEL_1', 'score': 0.8538534641265869},
#  {'label': 'LABEL_1', 'score': 0.8751925826072693},
#  {'label': 'LABEL_0', 'score': 0.9417484998703003},
#  {'label': 'LABEL_0', 'score': 0.9601202607154846},
#  {'label': 'LABEL_0', 'score': 0.9584603309631348},
#  {'label': 'LABEL_1', 'score': 0.8930808305740356},
#  {'label': 'LABEL_0', 'score': 0.9447019100189209},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_1', 'score': 0.9169166088104248},
#  {'label': 'LABEL_0', 'score': 0.9398759603500366},
#  {'label': 'LABEL_1', 'score': 0.9581508636474609},
#  {'label': 'LABEL_1', 'score': 0.9460071921348572},
#  {'label': 'LABEL_1', 'score': 0.9010941386222839},
#  {'label': 'LABEL_1', 'score': 0.6193024516105652},
#  {'label': 'LABEL_0', 'score': 0.924308717250824},
#  {'label': 'LABEL_1', 'score': 0.8781038522720337},
#  {'label': 'LABEL_0', 'score': 0.945099949836731},
#  {'label': 'LABEL_0', 'score': 0.9341343641281128},
#  {'label': 'LABEL_0', 'score': 0.700158953666687},
#  {'label': 'LABEL_1', 'score': 0.9106137156486511},
#  {'label': 'LABEL_0', 'score': 0.9544000029563904},
#  {'label': 'LABEL_0', 'score': 0.9450861215591431},
#  {'label': 'LABEL_1', 'score': 0.900253415107727},
#  {'label': 'LABEL_1', 'score': 0.9561785459518433},
#  {'label': 'LABEL_1', 'score': 0.8656871318817139},
#  {'label': 'LABEL_0', 'score': 0.9546412229537964},
#  {'label': 'LABEL_0', 'score': 0.9394631385803223},
#  {'label': 'LABEL_1', 'score': 0.6019634008407593},
#  {'label': 'LABEL_0', 'score': 0.9571458697319031},
#  {'label': 'LABEL_0', 'score': 0.959955096244812},
#  {'label': 'LABEL_1', 'score': 0.9521405696868896},
#  {'label': 'LABEL_1', 'score': 0.9044437408447266},
#  {'label': 'LABEL_0', 'score': 0.9581772685050964},
#  {'label': 'LABEL_1', 'score': 0.6882067918777466},
#  {'label': 'LABEL_0', 'score': 0.8893795013427734},
#  {'label': 'LABEL_1', 'score': 0.8719161152839661},
#  {'label': 'LABEL_0', 'score': 0.9518651962280273},
#  {'label': 'LABEL_1', 'score': 0.7536557912826538},
#  {'label': 'LABEL_1', 'score': 0.7449585795402527},
#  {'label': 'LABEL_0', 'score': 0.9488402009010315},
#  {'label': 'LABEL_0', 'score': 0.9557715654373169},
#  {'label': 'LABEL_0', 'score': 0.8797975182533264}]

# %%
def get_label(d):
  return int(d['label'].split('_')[1])
test_pred = [get_label(d) for  d in test_pred]

# %%
print('acc:',accuracy_score(split['test']['label'],test_pred))
# Out:
# acc: 0.7274939172749392

# %%
print('f1:',f1_score(split['test']['label'],test_pred,average='macro'))
# Out:
# f1: 0.5970640247150315

# %%
def plot_cm(cm):
  classes = ['Publisher','Book','Platform']
  df_cm = pd.DataFrame(cm,index=classes,columns=classes)
  ax = sns.heatmap(df_cm,annot=True,fmt='g')

cm = confusion_matrix(split['test']['label'],test_pred,normalize='true')

# %%
plot_cm(cm)
